# %%
# 🟢 Instalar bibliotecas necessárias!pip install pandas openpyxl matplotlib seaborn -q# 🟢 Importar bibliotecasimport pandas as pdimport matplotlib.pyplot as pltimport seaborn as snsfrom google.colab import filesfrom datetime import datetime# 🟢 Dados simuladosdados = [  {    "Nome do Produto": "TrichoPower",    "Tipo de Uso": "Inoculante",    "Situa\u00e7\u00e3o": "Ativo",    "Microrganismos": "Trichoderma harzianum",    "Empresa": "BioAgroTech",    "N\u00famero de Registro": "12345",    "Detentor do Registro": "BioAgro Holding",    "Estado": "GO",    "Cidade": "Rio Verde",    "Contato": "(64) 99999-0000",    "Email": "contato@bioagrotech.com.br"  },  {    "Nome do Produto": "Bacillus Boost",    "Tipo de Uso": "Controle de Pragas",    "Situa\u00e7\u00e3o": "Ativo",    "Microrganismos": "Bacillus thuringiensis",    "Empresa": "AgroBio Ltda",    "N\u00famero de Registro": "67890",    "Detentor do Registro": "AgroBio Group",    "Estado": "SP",    "Cidade": "Campinas",    "Contato": "(19) 98888-7777",    "Email": "suporte@agrobio.com.br"  },  {    "Nome do Produto": "FungoMax",    "Tipo de Uso": "Biofungicida",    "Situa\u00e7\u00e3o": "Inativo",    "Microrganismos": "Beauveria bassiana",    "Empresa": "EcoFert",    "N\u00famero de Registro": "54321",    "Detentor do Registro": "EcoTech Solutions",    "Estado": "MG",    "Cidade": "Uberl\u00e2ndia",    "Contato": "(34) 97777-8888",    "Email": "vendas@ecofert.com"  }]# 🟢 Converter em DataFramedf = pd.DataFrame(dados)# 🟢 Exportar arquivoshoje = datetime.today().strftime('%d_%m_%Y')excel_name = f"bioinsumos_simulado_{hoje}.xlsx"csv_name = f"bioinsumos_simulado_{hoje}.csv"df.to_excel(excel_name, index=False)df.to_csv(csv_name, index=False)# 🟢 Gráfico por Tipo de Usoplt.figure(figsize=(8,5))sns.countplot(data=df, y="Tipo de Uso", order=df["Tipo de Uso"].value_counts().index)plt.title("Distribuição por Tipo de Uso")plt.xlabel("Quantidade")plt.ylabel("Tipo de Uso")plt.show()# 🟢 Gráfico por Estadoplt.figure(figsize=(8,5))sns.countplot(data=df, y="Estado", order=df["Estado"].value_counts().index)plt.title("Distribuição por Estado")plt.xlabel("Quantidade")plt.ylabel("Estado")plt.show()# 🟢 Disponibilizar arquivos para downloadfiles.download(excel_name)files.download(csv_name)
